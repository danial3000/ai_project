# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("project datas/Phase 1/Linear Regression/train.csv")
df
# Out:
#               id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0              0                 5                   8                5
# 1              1                 6                   7                4
# 2              2                 6                   5                6
# 3              3                 3                   4                6
# 4              4                 5                   3                2
# ...          ...               ...                 ...              ...
# 1048570  1048570                 6                   6                5
# 1048571  1048571                 5                   4                4
# 1048572  1048572                 3                   5                5
# 1048573  1048573                 4                   4                2
# 1048574  1048574                 5                   3                4
#
#          Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0                    8             6              4            4          3
# 1                    4             8              8            3          5
# 2                    7             3              7            1          5
# 3                    5             4              8            4          7
# 4                    6             4              4            3          3
# ...                ...           ...            ...          ...        ...
# 1048570              3             5              3            7          4
# 1048571              5             5              4            5          3
# 1048572              9             5              6            1          4
# 1048573              3             4              7           11          3
# 1048574              5             3              2            8         10
#
#          AgriculturalPractices  ...  DrainageSystems  CoastalVulnerability  \
# 0                            3  ...                5                     3
# 1                            4  ...                7                     2
# 2                            4  ...                7                     3
# 3                            6  ...                2                     4
# 4                            3  ...                2                     2
# ...                        ...  ...              ...                   ...
# 1048570                      4  ...                3                     6
# 1048571                      6  ...                3                     4
# 1048572                      5  ...                8                     5
# 1048573                      3  ...                6                     3
# 1048574                      5  ...                5                     6
#
#          Landslides  Watersheds  DeterioratingInfrastructure  PopulationScore  \
# 0                 3           5                            4                7
# 1                 0           3                            5                3
# 2                 7           5                            6                8
# 3                 7           4                            4                6
# 4                 6           6                            4                1
# ...             ...         ...                          ...              ...
# 1048570           8           5                            4                6
# 1048571           6           3                            3                4
# 1048572           3           5                            3                6
# 1048573           7           1                            5                7
# 1048574           4           7                            5                6
#
#          WetlandLoss  InadequatePlanning  PoliticalFactors  FloodProbability
# 0                  5                   7                 3             0.445
# 1                  3                   4                 3             0.450
# 2                  2                   3                 3             0.530
# 3                  5                   7                 5             0.535
# 4                  2                   3                 5             0.415
# ...              ...                 ...               ...               ...
# 1048570            5                   5                 4             0.475
# 1048571            4                  10                 4             0.495
# 1048572            5                   7                 6             0.500
# 1048573            5                   6                 4             0.450
# 1048574            1                   6                 9             0.535
#
# [1048575 rows x 22 columns]

# %%
y = df['FloodProbability'].to_numpy()
x = df.drop(['id', 'FloodProbability'], axis=1).to_numpy()

# %%
x.shape
# Out:
# (1048575, 20)

# %%
weights = np.full(x.shape[1], 3, dtype=np.float64)
bias = 1
weights
# Out:
# array([3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3.,
#        3., 3., 3.])

# %%
def linear_regression(alpha, bias, w, x, y):
    rows, columns = x.shape
    for i in range(rows):
        selected_row = x[i,:]
        predict = np.dot(selected_row, w) + bias
        real = y[i]
        for j in range(columns):
            w[j] -= selected_row[j] * (predict - real) * 2 * alpha
        bias -= (predict - real) * 2 * alpha
    return (w, bias)

# %%
w, b = linear_regression(0.001, bias, weights, x, y)
w, b
# Out:
# (array([0.00504873, 0.00568381, 0.00379706, 0.00516321, 0.00499405,
#         0.00427365, 0.00449355, 0.00713613, 0.0065448 , 0.00488314,
#         0.00670211, 0.00498365, 0.0053885 , 0.00769764, 0.0054296 ,
#         0.00595668, 0.00522753, 0.00529077, 0.00563914, 0.00595365]),
#  -0.05179895159894438)

# %%
df.corr()
# Out:
#                                        id  MonsoonIntensity  \
# id                               1.000000          0.000394
# MonsoonIntensity                 0.000394          1.000000
# TopographyDrainage              -0.001846         -0.007255
# RiverManagement                 -0.000946         -0.007763
# Deforestation                   -0.000063         -0.007162
# Urbanization                     0.001028         -0.009026
# ClimateChange                   -0.000132         -0.008065
# DamsQuality                     -0.000062         -0.008134
# Siltation                       -0.000438         -0.007671
# AgriculturalPractices           -0.000102         -0.008022
# Encroachments                   -0.000861         -0.010372
# IneffectiveDisasterPreparedness -0.000624         -0.007641
# DrainageSystems                  0.000965         -0.009475
# CoastalVulnerability            -0.001526         -0.010264
# Landslides                       0.000679         -0.009308
# Watersheds                       0.000115         -0.008938
# DeterioratingInfrastructure     -0.000189         -0.008713
# PopulationScore                  0.001124         -0.009295
# WetlandLoss                      0.000590         -0.006281
# InadequatePlanning              -0.001674         -0.008459
# PoliticalFactors                 0.000103         -0.008639
# FloodProbability                -0.000594          0.189259
#
#                                  TopographyDrainage  RiverManagement  \
# id                                        -0.001846        -0.000946
# MonsoonIntensity                          -0.007255        -0.007763
# TopographyDrainage                         1.000000        -0.009952
# RiverManagement                           -0.009952         1.000000
# Deforestation                             -0.008854        -0.008134
# Urbanization                              -0.010346        -0.012134
# ClimateChange                             -0.009383        -0.008904
# DamsQuality                               -0.007322        -0.008904
# Siltation                                 -0.009779        -0.010433
# AgriculturalPractices                     -0.009123        -0.010465
# Encroachments                             -0.013043        -0.011746
# IneffectiveDisasterPreparedness           -0.010542        -0.010889
# DrainageSystems                           -0.010169        -0.011629
# CoastalVulnerability                      -0.012047        -0.010999
# Landslides                                -0.010209        -0.009145
# Watersheds                                -0.011338        -0.011216
# DeterioratingInfrastructure               -0.006912        -0.005587
# PopulationScore                           -0.010687        -0.006760
# WetlandLoss                               -0.009857        -0.010489
# InadequatePlanning                        -0.011831        -0.009786
# PoliticalFactors                          -0.012422        -0.011537
# FloodProbability                           0.187643         0.187202
#
#                                  Deforestation  Urbanization  ClimateChange  \
# id                                   -0.000063      0.001028      -0.000132
# MonsoonIntensity                     -0.007162     -0.009026      -0.008065
# TopographyDrainage                   -0.008854     -0.010346      -0.009383
# RiverManagement                      -0.008134     -0.012134      -0.008904
# Deforestation                         1.000000     -0.011909      -0.007640
# Urbanization                         -0.011909      1.000000      -0.011329
# ClimateChange                        -0.007640     -0.011329       1.000000
# DamsQuality                          -0.009438     -0.010701      -0.008485
# Siltation                            -0.011512     -0.009895      -0.009449
# AgriculturalPractices                -0.009958     -0.010301      -0.011323
# Encroachments                        -0.012969     -0.010747      -0.012441
# IneffectiveDisasterPreparedness      -0.009707     -0.012934      -0.011427
# DrainageSystems                      -0.010575     -0.012813      -0.009530
# CoastalVulnerability                 -0.012260     -0.014122      -0.013162
# Landslides                           -0.009302     -0.010867      -0.008885
# Watersheds                           -0.010583     -0.011672      -0.009797
# DeterioratingInfrastructure          -0.008498     -0.010336      -0.006062
# PopulationScore                      -0.011931     -0.010975      -0.010275
# WetlandLoss                          -0.011006     -0.011101      -0.009074
# InadequatePlanning                   -0.010415     -0.011341      -0.010887
# PoliticalFactors                     -0.010094     -0.013116      -0.011729
# FloodProbability                      0.184420      0.181316       0.185311
#
#                                  DamsQuality  Siltation  \
# id                                 -0.000062  -0.000438
# MonsoonIntensity                   -0.008134  -0.007671
# TopographyDrainage                 -0.007322  -0.009779
# RiverManagement                    -0.008904  -0.010433
# Deforestation                      -0.009438  -0.011512
# Urbanization                       -0.010701  -0.009895
# ClimateChange                      -0.008485  -0.009449
# DamsQuality                         1.000000  -0.009389
# Siltation                          -0.009389   1.000000
# AgriculturalPractices              -0.008833  -0.010478
# Encroachments                      -0.010877  -0.010585
# IneffectiveDisasterPreparedness    -0.009333  -0.009169
# DrainageSystems                    -0.010423  -0.010669
# CoastalVulnerability               -0.012325  -0.011715
# Landslides                         -0.010335  -0.009587
# Watersheds                         -0.009468  -0.009401
# DeterioratingInfrastructure        -0.009915  -0.006374
# PopulationScore                    -0.009497  -0.008223
# WetlandLoss                        -0.009814  -0.008938
# InadequatePlanning                 -0.011535  -0.008784
# PoliticalFactors                   -0.012708  -0.008289
# FloodProbability                    0.187676   0.186914
#
#                                  AgriculturalPractices  ...  DrainageSystems  \
# id                                           -0.000102  ...         0.000965
# MonsoonIntensity                             -0.008022  ...        -0.009475
# TopographyDrainage                           -0.009123  ...        -0.010169
# RiverManagement                              -0.010465  ...        -0.011629
# Deforestation                                -0.009958  ...        -0.010575
# Urbanization                                 -0.010301  ...        -0.012813
# ClimateChange                                -0.011323  ...        -0.009530
# DamsQuality                                  -0.008833  ...        -0.010423
# Siltation                                    -0.010478  ...        -0.010669
# AgriculturalPractices                         1.000000  ...        -0.011249
# Encroachments                                -0.012224  ...        -0.011702
# IneffectiveDisasterPreparedness              -0.010960  ...        -0.012857
# DrainageSystems                              -0.011249  ...         1.000000
# CoastalVulnerability                         -0.011818  ...        -0.013586
# Landslides                                   -0.010805  ...        -0.011319
# Watersheds                                   -0.009720  ...        -0.013020
# DeterioratingInfrastructure                  -0.008730  ...        -0.009819
# PopulationScore                              -0.009484  ...        -0.011909
# WetlandLoss                                  -0.011104  ...        -0.011546
# InadequatePlanning                           -0.010321  ...        -0.012927
# PoliticalFactors                             -0.011203  ...        -0.011951
# FloodProbability                              0.183365  ...         0.178971
#
#                                  CoastalVulnerability  Landslides  Watersheds  \
# id                                          -0.001526    0.000679    0.000115
# MonsoonIntensity                            -0.010264   -0.009308   -0.008938
# TopographyDrainage                          -0.012047   -0.010209   -0.011338
# RiverManagement                             -0.010999   -0.009145   -0.011216
# Deforestation                               -0.012260   -0.009302   -0.010583
# Urbanization                                -0.014122   -0.010867   -0.011672
# ClimateChange                               -0.013162   -0.008885   -0.009797
# DamsQuality                                 -0.012325   -0.010335   -0.009468
# Siltation                                   -0.011715   -0.009587   -0.009401
# AgriculturalPractices                       -0.011818   -0.010805   -0.009720
# Encroachments                               -0.016746   -0.011407   -0.013756
# IneffectiveDisasterPreparedness             -0.009704   -0.010041   -0.011581
# DrainageSystems                             -0.013586   -0.011319   -0.013020
# CoastalVulnerability                         1.000000   -0.013681   -0.011946
# Landslides                                  -0.013681    1.000000   -0.012073
# Watersheds                                  -0.011946   -0.012073    1.000000
# DeterioratingInfrastructure                 -0.009850   -0.007086   -0.010130
# PopulationScore                             -0.013368   -0.008651   -0.010136
# WetlandLoss                                 -0.012160   -0.010995   -0.012137
# InadequatePlanning                          -0.013804   -0.011113   -0.013766
# PoliticalFactors                            -0.013747   -0.010173   -0.011379
# FloodProbability                             0.177825    0.184926    0.181806
#
#                                  DeterioratingInfrastructure  PopulationScore  \
# id                                                 -0.000189         0.001124
# MonsoonIntensity                                   -0.008713        -0.009295
# TopographyDrainage                                 -0.006912        -0.010687
# RiverManagement                                    -0.005587        -0.006760
# Deforestation                                      -0.008498        -0.011931
# Urbanization                                       -0.010336        -0.010975
# ClimateChange                                      -0.006062        -0.010275
# DamsQuality                                        -0.009915        -0.009497
# Siltation                                          -0.006374        -0.008223
# AgriculturalPractices                              -0.008730        -0.009484
# Encroachments                                      -0.010500        -0.010496
# IneffectiveDisasterPreparedness                    -0.009851        -0.011716
# DrainageSystems                                    -0.009819        -0.011909
# CoastalVulnerability                               -0.009850        -0.013368
# Landslides                                         -0.007086        -0.008651
# Watersheds                                         -0.010130        -0.010136
# DeterioratingInfrastructure                         1.000000        -0.007336
# PopulationScore                                    -0.007336         1.000000
# WetlandLoss                                        -0.008801        -0.010859
# InadequatePlanning                                 -0.008376        -0.009801
# PoliticalFactors                                   -0.009187        -0.012567
# FloodProbability                                    0.190152         0.186285
#
#                                  WetlandLoss  InadequatePlanning  \
# id                                  0.000590           -0.001674
# MonsoonIntensity                   -0.006281           -0.008459
# TopographyDrainage                 -0.009857           -0.011831
# RiverManagement                    -0.010489           -0.009786
# Deforestation                      -0.011006           -0.010415
# Urbanization                       -0.011101           -0.011341
# ClimateChange                      -0.009074           -0.010887
# DamsQuality                        -0.009814           -0.011535
# Siltation                          -0.008938           -0.008784
# AgriculturalPractices              -0.011104           -0.010321
# Encroachments                      -0.010356           -0.012409
# IneffectiveDisasterPreparedness    -0.010562           -0.012465
# DrainageSystems                    -0.011546           -0.012927
# CoastalVulnerability               -0.012160           -0.013804
# Landslides                         -0.010995           -0.011113
# Watersheds                         -0.012137           -0.013766
# DeterioratingInfrastructure        -0.008801           -0.008376
# PopulationScore                    -0.010859           -0.009801
# WetlandLoss                         1.000000           -0.009538
# InadequatePlanning                 -0.009538            1.000000
# PoliticalFactors                   -0.011483           -0.011333
# FloodProbability                    0.183472            0.180800
#
#                                  PoliticalFactors  FloodProbability
# id                                       0.000103         -0.000594
# MonsoonIntensity                        -0.008639          0.189259
# TopographyDrainage                      -0.012422          0.187643
# RiverManagement                         -0.011537          0.187202
# Deforestation                           -0.010094          0.184420
# Urbanization                            -0.013116          0.181316
# ClimateChange                           -0.011729          0.185311
# DamsQuality                             -0.012708          0.187676
# Siltation                               -0.008289          0.186914
# AgriculturalPractices                   -0.011203          0.183365
# Encroachments                           -0.012110          0.178583
# IneffectiveDisasterPreparedness         -0.010372          0.182847
# DrainageSystems                         -0.011951          0.178971
# CoastalVulnerability                    -0.013747          0.177825
# Landslides                              -0.010173          0.184926
# Watersheds                              -0.011379          0.181806
# DeterioratingInfrastructure             -0.009187          0.190152
# PopulationScore                         -0.012567          0.186285
# WetlandLoss                             -0.011483          0.183472
# InadequatePlanning                      -0.011333          0.180800
# PoliticalFactors                         1.000000          0.182248
# FloodProbability                         0.182248          1.000000
#
# [22 rows x 22 columns]

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

def predict(x, w, bias):
    return np.dot(x, w) + bias

y_pred = predict(x, w, b)

mae = mean_absolute_error(y, y_pred)

mse = mean_squared_error(y, y_pred)

print(f"mean absolute error: {mae}")
print(f"mean squared error: {mse}")
# Out:
# Mean Absolute Error: 0.018740944369158127
# Mean Squared Error: 0.0006155452853692765

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

def linear_regression(alpha, bias, w, x, y, epochs):
    rows, columns = x.shape
    mse_list = []
    mae_list = []
    
    for epoch in range(epochs):
        total_mse = 0
        total_mae = 0
        for i in range(rows):
            selected_row = x[i,:]
            predict = np.dot(selected_row, w) + bias
            real = y[i]
            for j in range(columns):
                w[j] -= selected_row[j] * (predict - real) * 2 * alpha
            bias -= (predict - real) * 2 * alpha
            
            total_mse += (predict - real) ** 2
            total_mae += abs(predict - real)  
            
        mse = total_mse / rows
        mae = total_mae / rows
        mse_list.append(mse)
        mae_list.append(mae)
    
    return (w, bias, mse_list, mae_list)

def predict(x, w, bias):
    return np.dot(x, w) + bias

weights = np.full(x.shape[1], 20, dtype=np.float64)
bias = 15

epochs = 10 
alpha = 0.001
w, b, mse_list, mae_list = linear_regression(alpha, bias, weights, x, y, epochs)

y_pred = predict(x, w, b)

mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")

plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
plt.plot(range(epochs), mse_list, label='MSE', color='blue')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.title('MSE vs Epochs')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(range(epochs), mae_list, label='MAE', color='orange')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('MAE vs Epochs')
plt.legend()

plt.tight_layout()  
plt.show()
# Out:
# Mean Absolute Error: 0.01874095724089688
# Mean Squared Error: 0.0006155463273562727
